# %% [markdown]
# <a href="https://colab.research.google.com/github/Afitz19/Afitz19/blob/main/Converter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import Camelot but have ghostwriter installed

# %%
import camelot as cam

# %% [markdown]
# Download your pdf file to colab then copy its path you can use stream in this formatt or lettice

# %%
pdf = cam.read_pdf("/content/FY2021AssigmentList.pdf", pages ='1', flavor= "stream")

# %% [markdown]
# print the shortcut name

# %%
print(pdf)
# Out:
# <TableList n=1>

# %% [markdown]
# format the data frame

# %%
pdf[0].df
# Out:
#                      0                           1                        2  \
# 0   DISTRICT ACCOUNT #                 OWNERS NAME           ADDRESS STREET
# 1                   18  2067452 5922 CENTRAL AVENU                     AKIN
# 2                   20  2839082 ACKER KEITH C & LI                 CRANDALL
# 3                   17  1936574 ADEWUYI GBAYE & LU           1836 METZEROTT
# 4                   18  2064590 BANNISTER JACK G &                  DOPPLER
# 5                    8  0834879 BARNES PAUL & MARY                  HAWKINS
# 6                   14   1577238 BARTON BEATRICE B          GEORGE N PALMER
# 7                   14   1579010 BELLAMY CHARLOTTE                5605 GLEN
# 8                    5  0278200 BEST GEORGE & MARY               LIVINGSTON
# 9                    6          0643650 BONDS ROSA              2162 COUNTY
# 10                   6  0652982 BROTHER HOOD OF ME                1518 NOVA
# ...

# %% [markdown]
# Export converter by this format

# %%
table[0].df.to_excel('taxdeliquent_demo.xls')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   """Entry point for launching an IPython kernel.
