# %% [markdown]
# <a href="https://colab.research.google.com/github/Afitz19/Afitz19/blob/main/Social_Media_Reach_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import plotly.express as px
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from sklearn.model_selection import train_test_split
from sklearn.linear_model import PassiveAggressiveRegressor

# %%
df = pd.read_html('/content/stories.html', encoding='latin1')

# %%
df2 = pd.read_html('/content/index.html')

# %%
df2
# Out:
# [    0   1
#  0 NaN NaN
#  1 NaN NaN
#  2 NaN NaN]

# %%
df
# Out:
# [    0   1
#  0 NaN NaN
#  1 NaN NaN
#  2 NaN NaN,                  0                                     1
#  0        Device ID  06AF2A18-F190-4441-A180-785404A3AA61
#  1  Camera position                               unknown
#  2      Source type                          reel_reshare,                   0                                              1
#  0         ISO speed                                             80
#  1      Focal length                                           4.25
#  2        Lens model  iPhone 11 Pro back triple camera 4.25mm f/1.8
#  3          Software                                         15.2.1
#  4         Device ID           06AF2A18-F190-4441-A180-785404A3AA61
#  5        Scene type                                              1
#  6   Camera position                                           back
#  7         Lens make                                          Apple
#  8              Date                            2022:02:17 19:32:53
# ...

# %% [markdown]
# Donut chart showing insight per reach hashtags vs home page vs the explore page

# %%
home = social['From Home'].sum()
hashtags = social['From Hashtags'].sum()
explore = social ['From Explore'].sum()
other = social['From Other'].sum()

labels = ['From Home','From Hashtags','From Explore','Other']
values = [home, hashtags, explore, other]

donut = px.pie(social, values=values, names=labels, title='IG Impressions')

# %% [markdown]
# for most used word in post, and hastags

# %%
from PIL.Image import BILINEAR
, wordcloud
text = ' '.join(i for i in social.Caption)
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords,background_color='white').generate(text)
plt.style.use('classic')
plt.figure( figsize=(12,10))
plt.imshow(wordcloud, interpolation= 'bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# IG Distribution of home impresstions, hashtage and explore

# %%
plt.figure(figsize=(10,8))
plt.style.use('fivethirtyeight')
plt.title('distribution of impresstions home')
sns.distplot(social['From Home'])
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.style.use('fivethirtyeight')
plt.title('distribution of impresstions hashtags')
sns.distplot(social['From Hashtags'])
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.style.use('fivethirtyeight')
plt.title('distribution of impresstions Explore')
sns.distplot(social['From Explore'])
plt.show()

# %% [markdown]
# Linear regresstion number of impressions - number of likes

# %%
figure = px.scatter(data_frame= social, x='Impressions',y = 'Likes', size='Likes', trendline='ols', title = 'correlation between likes and impressions')
