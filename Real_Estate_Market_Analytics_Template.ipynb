# %% [markdown]
# <a href="https://colab.research.google.com/github/Afitz19/Afitz19/blob/main/Real_Estate_Market_Analytics_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('https://econdata.s3-us-west-2.amazonaws.com/Reports/Hotness/RDC_Inventory_Hotness_Metrics_County_History.csv', nrows=5000)

# %%
df.astype({'county_name':'object','cbsa_title': 'object','hotness_score':'float','supply_score':'float','demand_score':'float','median_dom_vs_us':'float'})
# Out:
#       month_date_yyyymm  county_fips    county_name  cbsa_code  \
# 0                202206         8077       mesa, co    24300.0
# 1                202206        21217     taylor, ky    15820.0
# 2                202206        27099      mower, mn    12380.0
# 3                202206        46083    lincoln, sd    43620.0
# 4                202206        36063    niagara, ny    15380.0
# ...                 ...          ...            ...        ...
# 4995             202203        42013      blair, pa    11020.0
# 4996             202203        55115    shawano, wi    43020.0
# 4997             202203         8043    fremont, co    15860.0
# 4998             202203        45027  clarendon, sc        NaN
# 4999             202203         5023   cleburne, ar        NaN
#
#                                  cbsa_title  nielsen_hh_rank  hotness_rank  \
# 0                        grand junction, co            421.0           962
# ...

# %%
sellers_market = (df.loc[:, 'hotness_score'] < 75) & (df.loc[:,'supply_score'] < 75) & (df.loc[:,'demand_score'] < 75)
df1m = df[sellers_market]

# %%
df1m.plot.scatter(x='hotness_rank', y='median_days_on_market')

# %%
df1m.plot.scatter(x='hotness_score', y='demand_score')

# %%
df1m.plot.scatter(x='hotness_score', y='hotness_rank')

# %%
df1m
# Out:
#       month_date_yyyymm  county_fips           county_name  cbsa_code  \
# 0                202206         8077              mesa, co    24300.0
# 1                202206        21217            taylor, ky    15820.0
# 3                202206        46083           lincoln, sd    43620.0
# 6                202206        29510  saint louis city, mo    41180.0
# 7                202206        18055            greene, in        NaN
# ...                 ...          ...                   ...        ...
# 4993             202203        48499              wood, tx        NaN
# 4995             202203        42013             blair, pa    11020.0
# 4997             202203         8043           fremont, co    15860.0
# 4998             202203        45027         clarendon, sc        NaN
# 4999             202203         5023          cleburne, ar        NaN
#
#               cbsa_title  nielsen_hh_rank  hotness_rank  hotness_rank_mm  \
# ...

# %%
df1m.corr()
# Out:
#                                        month_date_yyyymm  county_fips  \
# month_date_yyyymm                               1.000000     0.010908
# county_fips                                     0.010908     1.000000
# cbsa_code                                       0.032947     0.062064
# nielsen_hh_rank                                -0.027253     0.056649
# hotness_rank                                   -0.017483    -0.032437
# hotness_rank_mm                                 0.014780     0.036052
# hotness_rank_yy                                -0.002738     0.028473
# hotness_score                                   0.036062     0.030417
# supply_score                                    0.019084    -0.080924
# demand_score                                    0.034089     0.126609
# median_days_on_market                          -0.218165     0.049680
# median_days_on_market_mm                        0.274106    -0.044402
# ...

# %%
df.to_excel("July Real Estate Market.xlsx")
